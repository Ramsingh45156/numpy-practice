# %%
import numpy as np

# %%
np.arr=[[2,3,4,5],
     [2,4,5,4]]
arr
# Out:
# [[2, 3, 4, 5], [2, 4, 5, 4]]

# %%
np.shape(arr)
# Out:
# (2, 4)

# %%
d3=[[[1,2,3,4]],[[2,5,6,7]]]
d3
# Out:
# [[[1, 2, 3, 4]], [[2, 5, 6, 7]]]

# %%
np.shape(d3)
# Out:
# (2, 1, 4)

# %%
np.ndim(d3)
# Out:
# 3

# %%
y=np.array([12,34,54,53]);
print(y)
# Out:
# [12 34 54 53]

# %%
print(type(y))
# Out:
# <class 'numpy.ndarray'>

# %%
# %timeit [j**4 for j in range(1,9)]
# Out:
# 1.52 μs ± 188 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
a=np.array([1,2,4])

# %%
a
# Out:
# array([1, 2, 4])

# %%
a[0]
# Out:
# np.int64(1)

# %%
a[2]
# Out:
# np.int64(4)

# %%
arr=[];
for i in range(1,5):
    int_i=input("enter : ")
    arr.append(int_i)
print(np.array(arr))
# Out:
# enter :  A
# enter :  B
# enter :  C
# enter :  D
# ['A' 'B' 'C' 'D']

# %%
arr=[];
for i in range(1,5):
    int_i=int(input("enter : "))
    arr.append(int_i)
print(np.array(arr))
