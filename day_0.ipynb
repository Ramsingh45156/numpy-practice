# %%
import numpy as np

# %%
arr=np.array([1,2,3,4,5])
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
print(arr)
# Out:
# [1 2 3 4 5]

# %%
print(type(arr))        ## arr kis type ka object hai
                        ## type() tells the class/type of the object.
# Out:
# <class 'numpy.ndarray'>

# %%
print(arr.dtype)         ## array ke andar jo data hai uska type kya hai
                        ## dtype defines the data type of elements inside a NumPy array.
# Out:
# int64
