# %% [raw]
# #Arithmetic Operation in Numpy array
# np.add(a, b)        # addition
# np.subtract(a, b)   # subtraction
# np.multiply(a, b)   # multiplication
# np.divide(a, b)     # division
# np.mod(a, b)        # modulus
# np.power(a, 2)      # power

# %%
import numpy as np

# %%
arr = np.array([1,2,3,4])
arr
# Out:
# array([1, 2, 3, 4])

# %%
new_arr=arr+3   # sabhi element me 3 add ho jayega
new_arr
# Out:
# array([4, 5, 6, 7])

# %%
# add two Array
arr1=np.array([1,2,3,4,5])
arr2=np.array([6,7,8,9,10])
addedArr=arr1+arr2
addedArr
# Out:
# array([ 7,  9, 11, 13, 15])

# %%
# add Operation use
arr1=np.array([1,2,3,4,5])
arr2=np.array([6,7,8,9,10])
addedArr=np.add(arr1,arr2)
addedArr
# Out:
# array([ 7,  9, 11, 13, 15])

# %%
# add two 2D Array
arr1=np.array([[1,2,3],[4,5,6]])
arr2=np.array([[6,7,8],[9,10,11]])
addedArr=arr1+arr2
addedArr
# Out:
# array([[ 7,  9, 11],
#        [13, 15, 17]])

# %%
# add Operation use Two 2D array
# add two 2D Array
arr1=np.array([[1,2,3],[4,5,6]])
arr2=np.array([[6,7,8],[9,10,11]])
addedArr=np.add(arr1,arr2)
addedArr
# Out:
# array([[ 7,  9, 11],
#        [13, 15, 17]])
