# %%
import numpy as np

# %%
l=[]
for i in range(1,5):
    arr= input("Enter the Number:-")
    l.append(arr)
print(l)
# Out:
# Enter the Number:- 1
# Enter the Number:- 2
# Enter the Number:- 3
# Enter the Number:- 4
# ['1', '2', '3', '4']

# %%
l1=[]
for i in range(1,5):
    arr= input("Enter the Number:-") ## ye hamesa String value return karega
    l1.append(arr)
print(np.array(l1))
# Out:
# Enter the Number:- 1
# Enter the Number:- 2
# Enter the Number:- 3
# Enter the Number:- 4
# ['1' '2' '3' '4']

# %%
l1=[]
for i in range(1,5):
    arr= int(input("Enter the Number:-")) ## ye integer value return karega
    l1.append(arr)
print(np.array(l1))
# Out:
# Enter the Number:- 2
# Enter the Number:- 1
# Enter the Number:- 4
# Enter the Number:- 5
# [2 1 4 5]
